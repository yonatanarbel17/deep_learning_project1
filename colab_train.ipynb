# %% [markdown]
# # Chess Square Classifier - EfficientNet-B2 Training
# הרץ כל cell בסדר מלמעלה למטה

# %%
# 1. בדיקת GPU
# !nvidia-smi

# %%
# 2. הורדת הקוד והדאטה מגיטהאב
# !git clone https://github.com/yonatanarbel17/deep_learning_project1.git
# %cd deep_learning_project1
# !git checkout shick

# %%
# 3. התקנת dependencies
# !pip install -r requirements.txt -q

# %%
# 4. בדיקה שהדאטה נטען
# !ls data/

# %%
# 5. אימון EfficientNet-B2
# !python train.py \
    --data_root data/ \
    --backbone efficientnet_b2 \
    --epochs 30 \
    --batch_size 8 \
    --lr 1e-4 \
    --output_dir outputs/efficientnet_b2

# %%
# 6. הורדת המשקלות למחשב
from google.colab import files
files.download('outputs/efficientnet_b2/best_model.pth')
